# %%
# Opening a web page with web driver

# importing the webdriver library

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup

# %%
# Locating elements by id

chromeoptions=webdriver.ChromeOptions()

# %%
#chromeoptions.add_argument("--incognito")

# %%
driver=webdriver.Chrome(r"C:/Users/iprakash/Downloads/chromedriver_win32/chromedriver",options=chromeoptions)
driver.get("https://www.prokabaddi.com/sifeeds/kabaddi/static/json/6_team.json")

# %%
page_source_overwiew=driver.page_source

# %%
# Use Beautiful Soup Library to parse the html source page loaded in the driver object using lxml

soup=BeautifulSoup(page_source_overwiew)

# %%
#stats=soup.findAll('div',attrs={'class':'si-tbl-data'})
stats=soup.findAll('div',attrs={'class':'si-data-block'})

# %%
soup
# Out:
# <html><head></head><body><pre style="word-wrap: break-word; white-space: pre-wrap;">{
#   "bio": {
#     "team_id": 6,
#     "team_name": "Patna Pirates",
#     "short_name": "Patna",
#     "year_founded": "2014",
#     "match_short_code": "Pat",
#     "city_name": "Patna",
#     "writeup": "&lt;p&gt;Owned by KVS Energy and Sports Limited, Patna Pirates believes that the spirit of the pirate is the spirit of not letting go, of using the environment to advantage, of striking when the enemy is least aware. It is named not after the criminal meaning of the word but after the Greek word &amp;lsquo;peirin&amp;rsquo; which means &amp;ldquo;to attack&amp;rdquo;.&lt;/p&gt;\n&lt;p&gt;KVS Energy and Sports Limited, is owned by Rajesh Shah, Co Chairman and Managing Director of Mukand Ltd and his son Mr. Kaustubh Vir Shah.&lt;/p&gt;\n&lt;p&gt;Mukand is India&amp;rsquo;s leading integrated specialty steel producer and a manufacturer of heavy industrial machinery.  Mr. Rajesh Shah  is a third generation industrialist who has held several board positions in large Indian Public sector Units as well as multi national companies. He is the Past President of the Confederation of Indian Industries, and the Young Presidents&amp;rsquo; Organisation. Mr. Shah is also a keen follower of sport and is himself a fitness enthusiast.&lt;/p&gt;\n&lt;p&gt;Patna Pirates is his first venture into sporting territory.&lt;/p&gt;",
#     "venue_name": "Patliputra Sports Complex, Patna",
#     "venue_shortname": "Patliputra Sports Complex",
#     "venue_id": 6,
#     "coach_id": 808,
#     "coach": "Ram Mehar Singh",
#     "coach_shortname": "Ram Singh",
#     "official_website": "Patnapirates.net",
#     "facebook": "www.facebook.com/patnapirates/",
#     "twitter": "www.twitter.com/PatnaPirates",
#     "google_plus": null,
#     "instagram": "www.instagram.com/patnapirates\n",
#     "owner_id": null,
#     "owner": "Rajesh.V. Shah",
#     "owner_shortname": null,
#     "captain": "Pardeep Narwal",
#     "captain_shortname": "Pardeep Narwal",
#     "captain_id": 197
#   },
#   "over_all_stats": [
#     {
#       "series_id": 1,
#       "series_name": "Pro Kabaddi League Season 1, 2014",
#       "team_id": 6,
#       "name": "Patna Pirates",
#       "matches": 16,
#       "wins": 8,
#       "draws": 2,
#       "losses": 6,
#       "rank": "4",
#       "points": 45,
#       "score_difference": 45,
#       "all_outs": 18,
#       "top_raider_id": 92,
#       "top_raider": "Ravi Dalal",
#       "top_raider_value": 111,
#       "top_defender_id": 162,
#       "top_defender": "D. Suresh Kumar",
#       "top_defender_value": 28,
#       "top_allrounder_id": 142,
#       "top_allrounder": "Sandeep Narwal",
#       "top_all_rounder_value": 119,
#       "tackle_points": 142,
#       "capture_points": "",
#       "tackle_bonus_points": "",
#       "all_out_points": 36,
#       "extra_points": 10,
#       "tackles": 380,
#       "tackle_success_rate": 37,
#       "raids": 638,
#       "success_raids": 253,
#       "unsuccess_raids": 134,
#       "empty_raid": 251,
#       "success_raid_percent": 50,
#       "green_cards": 8,
#       "yellow_cards": 0,
#       "red_cards": 0,
#       "raid_bonus_points": 64,
#       "success_tackles": 124,
#       "defence_touch_points": 142,
#       "defending_bonus_points": 18,
#       "raid_touch_points": 252,
#       "unsuccesful_tackles": 256,
#       "total_raid_points": 316,
#       "total_defending_points": 142,
#       "super_tackles": 18,
#       "super_raids": 13,
#       "player_team": 0,
#       "highest_score": {
#         "match_id": 38,
#         "match_date": "2014-08-17",
#         "venue_id": 8,
#         "venue_name": "Rajiv Gandhi Indoor Stadium, Vizag",
#         "team_id": 3,
#         "team_name": "Jaipur Pink Panthers",
#         "highest_score": 52
#       },
#       "max_win_margin": {
#         "match_id": 38,
#         "match_date": "2014-08-17",
#         "venue_id": 8,
#         "venue_name": "Rajiv Gandhi Indoor Stadium, Vizag",
#         "team1_id": 3,
#         "team1_name": "Jaipur Pink Panthers",
#         "team1_score": 30,
#         "team2_id": 6,
#         "team2_name": "Patna Pirates",
#         "team2_score": 52,
#         "max_win_margin": 22
#       }
#     },
#     {
#       "series_id": 2,
#       "series_name": "Pro Kabaddi League Season 2, 2015",
#       "team_id": 6,
#       "name": "Patna Pirates",
#       "matches": 16,
#       "wins": 7,
#       "draws": 1,
#       "losses": 8,
#       "rank": "4",
#       "points": 41,
#       "score_difference": 59,
#       "all_outs": 13,
#       "top_raider_id": 211,
#       "top_raider": "Deepak Narwal",
#       "top_raider_value": 57,
#       "top_defender_id": 142,
#       "top_defender": "Sandeep Narwal",
#       "top_defender_value": 37,
#       "top_allrounder_id": 142,
#       "top_allrounder": "Sandeep Narwal",
#       "top_all_rounder_value": 83,
#       "tackle_points": 164,
#       "capture_points": "",
#       "tackle_bonus_points": "",
#       "all_out_points": 26,
#       "extra_points": 26,
#       "tackles": 376,
#       "tackle_success_rate": 44,
#       "raids": 701,
#       "success_raids": 182,
#       "unsuccess_raids": 159,
#       "empty_raid": 360,
#       "success_raid_percent": 33,
#       "green_cards": 10,
#       "yellow_cards": 1,
#       "red_cards": 0,
#       "raid_bonus_points": 43,
#       "success_tackles": 152,
#       "defence_touch_points": 164,
#       "defending_bonus_points": 13,
#       "raid_touch_points": 185,
#       "unsuccesful_tackles": 224,
#       "total_raid_points": 228,
#       "total_defending_points": 164,
#       "super_tackles": 13,
#       "super_raids": 4,
#       "player_team": 0,
#       "highest_score": {
#         "match_id": 85,
#         "match_date": "2015-07-31",
#         "venue_id": 6,
#         "venue_name": "Patliputra Sports Complex, Patna",
#         "team_id": 2,
#         "team_name": "Dabang Delhi K.C.",
#         "highest_score": 39
#       },
#       "max_win_margin": {
#         "match_id": 115,
#         "match_date": "2015-08-18",
#         "venue_id": 7,
#         "venue_name": "Shree Shiv Chhatrapati Sports Complex, Pune",
#         "team1_id": 7,
#         "team1_name": "Puneri Paltan",
#         "team1_score": 21,
#         "team2_id": 6,
#         "team2_name": "Patna Pirates",
#         "team2_score": 38,
#         "max_win_margin": 17
#       }
#     },
#     {
#       "series_id": 3,
#       "series_name": "Pro Kabaddi League Season 3, 2016",
#       "team_id": 6,
#       "name": "Patna Pirates",
#       "matches": 16,
#       "wins": 12,
#       "draws": 2,
#       "losses": 2,
#       "rank": "2",
#       "points": 58,
#       "score_difference": -46,
#       "all_outs": 30,
#       "top_raider_id": 197,
#       "top_raider": "Pardeep Narwal",
#       "top_raider_value": 116,
#       "top_defender_id": 142,
#       "top_defender": "Sandeep Narwal",
#       "top_defender_value": 55,
#       "top_allrounder_id": 142,
#       "top_allrounder": "Sandeep Narwal",
#       "top_all_rounder_value": 64,
#       "tackle_points": 182,
#       "capture_points": "",
#       "tackle_bonus_points": "",
#       "all_out_points": 60,
#       "extra_points": 28,
#       "tackles": 405,
#       "tackle_success_rate": 45,
#       "raids": 703,
#       "success_raids": 241,
#       "unsuccess_raids": 129,
#       "empty_raid": 333,
#       "success_raid_percent": 46,
#       "green_cards": 4,
#       "yellow_cards": 2,
#       "red_cards": 0,
#       "raid_bonus_points": 52,
#       "success_tackles": 175,
#       "defence_touch_points": 182,
#       "defending_bonus_points": 7,
#       "raid_touch_points": 272,
#       "unsuccesful_tackles": 230,
#       "total_raid_points": 324,
#       "total_defending_points": 182,
#       "super_tackles": 7,
#       "super_raids": 16,
#       "player_team": 0,
#       "highest_score": {
#         "match_id": 166,
#         "match_date": "2016-02-25",
#         "venue_id": 2,
#         "venue_name": "Thyagaraj Sports Complex, Delhi",
#         "team_id": 2,
#         "team_name": "Dabang Delhi K.C.",
#         "highest_score": 67
#       },
#       "max_win_margin": {
#         "match_id": 166,
#         "match_date": "2016-02-25",
#         "venue_id": 2,
#         "venue_name": "Thyagaraj Sports Complex, Delhi",
#         "team1_id": 2,
#         "team1_name": "Dabang Delhi K.C.",
#         "team1_score": 34,
#         "team2_id": 6,
#         "team2_name": "Patna Pirates",
#         "team2_score": 67,
#         "max_win_margin": 33
#       }
#     },
#     {
#       "series_id": 4,
#       "series_name": "Pro Kabaddi League Season 4, 2016",
#       "team_id": 6,
#       "name": "Patna Pirates",
#       "matches": 16,
#       "wins": 12,
#       "draws": 0,
#       "losses": 4,
#       "rank": "1",
#       "points": 52,
#       "score_difference": 38,
#       "all_outs": 19,
#       "top_raider_id": 197,
#       "top_raider": "Pardeep Narwal",
#       "top_raider_value": 131,
#       "top_defender_id": 259,
#       "top_defender": "Fazel Atrachali",
#       "top_defender_value": 52,
#       "top_allrounder_id": 252,
#       "top_allrounder": "Kuldeep Singh",
#       "top_all_rounder_value": 42,
#       "tackle_points": 171,
#       "capture_points": "",
#       "tackle_bonus_points": "",
#       "all_out_points": 38,
#       "extra_points": 19,
#       "tackles": 332,
#       "tackle_success_rate": 52,
#       "raids": 692,
#       "success_raids": 206,
#       "unsuccess_raids": 152,
#       "empty_raid": 334,
#       "success_raid_percent": 38,
#       "green_cards": 7,
#       "yellow_cards": 1,
#       "red_cards": 0,
#       "raid_bonus_points": 40,
#       "success_tackles": 145,
#       "defence_touch_points": 171,
#       "defending_bonus_points": 27,
#       "raid_touch_points": 224,
#       "unsuccesful_tackles": 187,
#       "total_raid_points": 264,
#       "total_defending_points": 171,
#       "super_tackles": 27,
#       "super_raids": 7,
#       "player_team": 0,
#       "highest_score": {
#         "match_id": 214,
#         "match_date": "2016-07-14",
#         "venue_id": 1,
#         "venue_name": "Sree Kanteerava Stadium, Bengaluru",
#         "team_id": 1,
#         "team_name": "Bengaluru Bulls",
#         "highest_score": 38
#       },
#       "max_win_margin": {
#         "match_id": 214,
#         "match_date": "2016-07-14",
#         "venue_id": 1,
#         "venue_name": "Sree Kanteerava Stadium, Bengaluru",
#         "team1_id": 1,
#         "team1_name": "Bengaluru Bulls",
#         "team1_score": 23,
#         "team2_id": 6,
#         "team2_name": "Patna Pirates",
#         "team2_score": 38,
#         "max_win_margin": 15
#       }
#     },
#     {
#       "series_id": 8,
#       "series_name": "Pro Kabaddi League Season 5, 2017",
#       "team_id": 6,
#       "name": "Patna Pirates",
#       "matches": 26,
#       "wins": 14,
#       "draws": 5,
#       "losses": 7,
#       "rank": "2",
#       "points": 71,
#       "score_difference": 11,
#       "all_outs": 55,
#       "top_raider_id": 197,
#       "top_raider": "Pardeep Narwal",
#       "top_raider_value": 369,
#       "top_defender_id": 579,
#       "top_defender": "Jaideep",
#       "top_defender_value": 71,
#       "top_allrounder_id": 745,
#       "top_allrounder": "Vijay",
#       "top_all_rounder_value": 64,
#       "tackle_points": 252,
#       "capture_points": "",
#       "tackle_bonus_points": "",
#       "all_out_points": 110,
#       "extra_points": 51,
#       "tackles": 625,
#       "tackle_success_rate": 40,
#       "raids": 1173,
#       "success_raids": 487,
#       "unsuccess_raids": 238,
#       "empty_raid": 448,
#       "success_raid_percent": 54,
#       "green_cards": 10,
#       "yellow_cards": 2,
#       "red_cards": 0,
#       "raid_bonus_points": 129,
#       "success_tackles": 226,
#       "defence_touch_points": 252,
#       "defending_bonus_points": 27,
#       "raid_touch_points": 508,
#       "unsuccesful_tackles": 399,
#       "total_raid_points": 637,
#       "total_defending_points": 252,
#       "super_tackles": 27,
#       "super_raids": 26,
#       "player_team": 0,
#       "highest_score": {
#         "match_id": 419,
#         "match_date": "2017-10-23",
#         "venue_id": 5,
#         "venue_name": "Dome, NSCI, SVP Stadium, Mumbai",
#         "team_id": 28,
#         "team_name": "Haryana Steelers",
#         "highest_score": 69
#       },
#       "max_win_margin": {
#         "match_id": 419,
#         "match_date": "2017-10-23",
#         "venue_id": 5,
#         "venue_name": "Dome, NSCI, SVP Stadium, Mumbai",
#         "team1_id": 6,
#         "team1_name": "Patna Pirates",
#         "team1_score": 69,
#         "team2_id": 28,
#         "team2_name": "Haryana Steelers",
#         "team2_score": 30,
#         "max_win_margin": 39
#       }
#     },
#     {
#       "series_id": 26,
#       "series_name": "Pro Kabaddi League Season 6, 2018",
#       "team_id": 6,
#       "name": "Patna Pirates",
#       "matches": 22,
#       "wins": 9,
#       "draws": 2,
#       "losses": 11,
#       "rank": "4",
#       "points": 55,
#       "score_difference": 91,
#       "all_outs": 30,
#       "top_raider_id": 197,
#       "top_raider": "Pardeep Narwal",
#       "top_raider_value": 233,
#       "top_defender_id": 579,
#       "top_defender": "Jaideep",
#       "top_defender_value": 58,
#       "top_allrounder_id": 745,
#       "top_allrounder": "Vijay",
#       "top_all_rounder_value": 73,
#       "tackle_points": 201,
#       "capture_points": "",
#       "tackle_bonus_points": "",
#       "all_out_points": 60,
#       "extra_points": 42,
#       "tackles": 555,
#       "tackle_success_rate": 36,
#       "raids": 934,
#       "success_raids": 406,
#       "unsuccess_raids": 226,
#       "empty_raid": 302,
#       "success_raid_percent": 53,
#       "green_cards": 11,
#       "yellow_cards": 0,
#       "red_cards": 0,
#       "raid_bonus_points": 120,
#       "success_tackles": 186,
#       "defence_touch_points": 201,
#       "defending_bonus_points": 16,
#       "raid_touch_points": 376,
#       "unsuccesful_tackles": 369,
#       "total_raid_points": 496,
#       "total_defending_points": 201,
#       "super_tackles": 16,
#       "super_raids": 11,
#       "player_team": 0,
#       "highest_score": {
#         "match_id": 725,
#         "match_date": "2018-12-07",
#         "venue_id": 8,
#         "venue_name": "Rajiv Gandhi Indoor Stadium, Vizag",
#         "team_id": 7,
#         "team_name": "Puneri Paltan",
#         "highest_score": 53
#       },
#       "max_win_margin": {
#         "match_id": 682,
#         "match_date": "2018-11-10",
#         "venue_id": 5,
#         "venue_name": "Dome, NSCI, SVP Stadium, Mumbai",
#         "team1_id": 6,
#         "team1_name": "Patna Pirates",
#         "team1_score": 50,
#         "team2_id": 4,
#         "team2_name": "Bengal Warriors",
#         "team2_score": 30,
#         "max_win_margin": 20
#       }
#     },
#     {
#       "series_id": 49,
#       "series_name": "Pro Kabaddi League Season 7, 2019",
#       "team_id": 6,
#       "name": "Patna Pirates",
#       "matches": 18,
#       "wins": 6,
#       "draws": 1,
#       "losses": 11,
#       "rank": "9",
#       "points": 39,
#       "score_difference": 36,
#       "all_outs": 26,
#       "top_raider_id": 197,
#       "top_raider": "Pardeep Narwal",
#       "top_raider_value": 224,
#       "top_defender_id": 637,
#       "top_defender": "Neeraj Kumar",
#       "top_defender_value": 50,
#       "top_allrounder_id": 249,
#       "top_allrounder": "Hadi Oshtorak",
#       "top_all_rounder_value": 42,
#       "tackle_points": 185,
#       "capture_points": "",
#       "tackle_bonus_points": "",
#       "all_out_points": 52,
#       "extra_points": 23,
#       "tackles": 423,
#       "tackle_success_rate": 44,
#       "raids": 761,
#       "success_raids": 269,
#       "unsuccess_raids": 176,
#       "empty_raid": 316,
#       "success_raid_percent": 45,
#       "green_cards": 10,
#       "yellow_cards": 0,
#       "red_cards": 0,
#       "raid_bonus_points": 67,
#       "success_tackles": 162,
#       "defence_touch_points": 185,
#       "defending_bonus_points": 23,
#       "raid_touch_points": 274,
#       "unsuccesful_tackles": 261,
#       "total_raid_points": 341,
#       "total_defending_points": 185,
#       "super_tackles": 23,
#       "super_raids": 12,
#       "player_team": 0,
#       "highest_score": {
#         "match_id": 1776,
#         "match_date": "2019-09-15",
#         "venue_id": 7,
#         "venue_name": "Shree Shiv Chhatrapati Sports Complex, Pune",
#         "team_id": 7,
#         "team_name": "Puneri Paltan",
#         "highest_score": 55
#       },
#       "max_win_margin": {
#         "match_id": 1767,
#         "match_date": "2019-09-09",
#         "venue_id": 4,
#         "venue_name": "Netaji Subhash Chandra Bose Indoor Stadium, Kolkata",
#         "team1_id": 29,
#         "team1_name": "Tamil Thalaivas",
#         "team1_score": 25,
#         "team2_id": 6,
#         "team2_name": "Patna Pirates",
#         "team2_score": 51,
#         "max_win_margin": 26
#       }
#     },
#     {
#       "series_id": 0,
#       "series_name": "",
#       "team_id": 6,
#       "name": "Patna Pirates",
#       "matches": 130,
#       "wins": 68,
#       "draws": 13,
#       "losses": 49,
#       "rank": "-",
#       "points": 361,
#       "score_difference": 234,
#       "all_outs": 191,
#       "top_raider_id": 197,
#       "top_raider": "Pardeep Narwal",
#       "top_raider_value": 1073,
#       "top_defender_id": 579,
#       "top_defender": "Jaideep",
#       "top_defender_value": 176,
#       "top_allrounder_id": 142,
#       "top_allrounder": "Sandeep Narwal",
#       "top_all_rounder_value": 266,
#       "tackle_points": 1297,
#       "capture_points": "",
#       "tackle_bonus_points": "",
#       "all_out_points": 382,
#       "extra_points": 199,
#       "tackles": 3096,
#       "tackle_success_rate": 42,
#       "raids": 5602,
#       "success_raids": 2044,
#       "unsuccess_raids": 1214,
#       "empty_raid": 2344,
#       "success_raid_percent": 47,
#       "green_cards": 60,
#       "yellow_cards": 6,
#       "red_cards": 0,
#       "raid_bonus_points": 515,
#       "success_tackles": 1170,
#       "defence_touch_points": 1297,
#       "defending_bonus_points": 131,
#       "raid_touch_points": 2091,
#       "unsuccesful_tackles": 1926,
#       "total_raid_points": 2606,
#       "total_defending_points": 1297,
#       "super_tackles": 131,
#       "super_raids": 89,
#       "player_team": 0,
#       "highest_score": {
#         "match_id": 419,
#         "match_date": "2017-10-23",
#         "venue_id": 5,
#         "venue_name": "Dome, NSCI, SVP Stadium, Mumbai",
#         "team_id": 28,
#         "team_name": "Haryana Steelers",
#         "highest_score": 69
#       },
#       "max_win_margin": {
#         "match_id": 419,
#         "match_date": "2017-10-23",
#         "venue_id": 5,
#         "venue_name": "Dome, NSCI, SVP Stadium, Mumbai",
#         "team1_id": 6,
#         "team1_name": "Patna Pirates",
#         "team1_score": 69,
#         "team2_id": 28,
#         "team2_name": "Haryana Steelers",
#         "team2_score": 30,
#         "max_win_margin": 39
#       },
#       "h2h": [
#         {
#           "team_id": 1,
#           "team_name": "Bengaluru Bulls",
#           "total_points": 586,
#           "total_raid_points": 322,
#           "total_tackle_points": 190,
#           "total_allout_points": 48,
#           "extra_points": 26,
#           "super_10s": 10,
#           "high_5s": 12
#         },
#         {
#           "team_id": 2,
#           "team_name": "Dabang Delhi K.C.",
#           "total_points": 398,
#           "total_raid_points": 226,
#           "total_tackle_points": 112,
#           "total_allout_points": 40,
#           "extra_points": 20,
#           "super_10s": 6,
#           "high_5s": 2
#         },
#         {
#           "team_id": 3,
#           "team_name": "Jaipur Pink Panthers",
#           "total_points": 442,
#           "total_raid_points": 242,
#           "total_tackle_points": 144,
#           "total_allout_points": 40,
#           "extra_points": 16,
#           "super_10s": 5,
#           "high_5s": 10
#         },
#         {
#           "team_id": 4,
#           "team_name": "Bengal Warriors",
#           "total_points": 539,
#           "total_raid_points": 314,
#           "total_tackle_points": 162,
#           "total_allout_points": 44,
#           "extra_points": 19,
#           "super_10s": 12,
#           "high_5s": 7
#         },
#         {
#           "team_id": 5,
#           "team_name": "U Mumba",
#           "total_points": 413,
#           "total_raid_points": 236,
#           "total_tackle_points": 125,
#           "total_allout_points": 30,
#           "extra_points": 22,
#           "super_10s": 6,
#           "high_5s": 5
#         },
#         {
#           "team_id": 7,
#           "team_name": "Puneri Paltan",
#           "total_points": 546,
#           "total_raid_points": 307,
#           "total_tackle_points": 154,
#           "total_allout_points": 58,
#           "extra_points": 27,
#           "super_10s": 8,
#           "high_5s": 7
#         },
#         {
#           "team_id": 8,
#           "team_name": "Telugu Titans",
#           "total_points": 569,
#           "total_raid_points": 350,
#           "total_tackle_points": 156,
#           "total_allout_points": 40,
#           "extra_points": 23,
#           "super_10s": 11,
#           "high_5s": 3
#         },
#         {
#           "team_id": 28,
#           "team_name": "Haryana Steelers",
#           "total_points": 202,
#           "total_raid_points": 138,
#           "total_tackle_points": 45,
#           "total_allout_points": 16,
#           "extra_points": 3,
#           "super_10s": 7,
#           "high_5s": 2
#         },
#         {
#           "team_id": 29,
#           "team_name": "Tamil Thalaivas",
#           "total_points": 294,
#           "total_raid_points": 179,
#           "total_tackle_points": 73,
#           "total_allout_points": 30,
#           "extra_points": 12,
#           "super_10s": 8,
#           "high_5s": 3
#         },
#         {
#           "team_id": 30,
#           "team_name": "U.P. Yoddha",
#           "total_points": 300,
#           "total_raid_points": 186,
#           "total_tackle_points": 72,
#           "total_allout_points": 24,
#           "extra_points": 18,
#           "super_10s": 8,
#           "high_5s": 1
#         },
#         {
#           "team_id": 31,
#           "team_name": "Gujarat Fortunegiants",
#           "total_points": 195,
#           "total_raid_points": 106,
#           "total_tackle_points": 64,
#           "total_allout_points": 12,
#           "extra_points": 13,
#           "super_10s": 2,
#           "high_5s": 3
#         }
#       ],
#       "titles": {
#         "total": 3,
#         "title_details": [
#           {
#             "id": 3,
#             "series_name": "Pro Kabaddi League Season 3, 2016"
#           },
#           {
#             "id": 4,
#             "series_name": "Pro Kabaddi League Season 4, 2016"
#           },
#           {
#             "id": 8,
#             "series_name": "Pro Kabaddi League Season 5, 2017"
#           }
#         ]
#       }
#     }
#   ],
#   "language_lookup": {
#     "bio_keys_translation": {
#       "team_id": "Team Id",
#       "team_name": "Team Name",
#       "short_name": "Short Name",
#       "year_founded": "Year Founded",
#       "match_short_code": "Match Short Code",
#       "city_name": "City Name",
#       "writeup": "Writeup",
#       "venue_name": "Venue Name",
#       "venue_shortname": "Venue Shortname",
#       "venue_id": "Venue Id",
#       "coach_id": "Coach Id",
#       "coach": "Coach",
#       "coach_shortname": "Coach Shortname",
#       "official_website": "Official Website",
#       "facebook": "Facebook",
#       "twitter": "Twitter",
#       "google_plus": "Google Plus",
#       "instagram": "Instagram",
#       "owner_id": "Owner Id",
#       "owner": "Owner",
#       "owner_shortname": "Owner Shortname",
#       "captain": "Captain",
#       "captain_shortname": "Captain Shortname",
#       "captain_id": "Captain Id"
#     },
#     "stats_keys_translation": {
#       "series_id": "Series Id",
#       "series_name": "Series Name",
#       "team_id": "Team Id",
#       "name": "Name",
#       "matches": "Matches",
#       "wins": "Wins",
#       "draws": "Draws",
#       "losses": "Losses",
#       "rank": "Rank",
#       "points": "Points",
#       "score_difference": "Score Difference",
#       "all_outs": "All Outs",
#       "top_raider_id": "Top Raider Id",
#       "top_raider": "Top Raider",
#       "top_raider_value": "Top Raider Value",
#       "top_defender_id": "Top Defender Id",
#       "top_defender": "Top Defender",
#       "top_defender_value": "Top Defender Value",
#       "top_allrounder_id": "Top Allrounder Id",
#       "top_allrounder": "Top Allrounder",
#       "top_all_rounder_value": "Top All Rounder Value",
#       "tackle_points": "Tackle Points",
#       "capture_points": "Capture Points",
#       "tackle_bonus_points": "Tackle Bonus Points",
#       "all_out_points": "All Out Points",
#       "extra_points": "Extra Points",
#       "tackles": "Tackles",
#       "tackle_success_rate": "Tackle Success Rate",
#       "raids": "Raids",
#       "success_raids": "Success Raids",
#       "unsuccess_raids": "Unsuccess Raids",
#       "empty_raid": "Empty Raid",
#       "success_raid_percent": "Success Raid Percent",
#       "green_cards": "Green Cards",
#       "yellow_cards": "Yellow Cards",
#       "red_cards": "Red Cards",
#       "raid_bonus_points": "Raid Bonus Points",
#       "success_tackles": "Success Tackles",
#       "defence_touch_points": "Defence Touch Points",
#       "defending_bonus_points": "Defending Bonus Points",
#       "raid_touch_points": "Raid Touch Points",
#       "unsuccesful_tackles": "Unsuccesful Tackles",
#       "total_raid_points": "Total Raid Points",
#       "total_defending_points": "Total Defending Points",
#       "super_tackles": "Super Tackles",
#       "super_raids": "Super Raids",
#       "player_team": "Player Team"
#     }
#   }
# }</pre></body></html>

# %%
import pandas as pd
import numpy as np
